# %%
import os
import urllib
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

data = pd.read_csv("datasets/data.csv")

data
# Out:
#      Message  Global__NewConfirmed  Global__TotalConfirmed  Global__NewDeaths  \
# 0        NaN              812078.0              88847614.0            14780.0
# 1        NaN                   NaN                     NaN                NaN
# 2        NaN                   NaN                     NaN                NaN
# 3        NaN                   NaN                     NaN                NaN
# 4        NaN                   NaN                     NaN                NaN
# ..       ...                   ...                     ...                ...
# 187      NaN                   NaN                     NaN                NaN
# 188      NaN                   NaN                     NaN                NaN
# 189      NaN                   NaN                     NaN                NaN
# 190      NaN                   NaN                     NaN                NaN
# 191      NaN                   NaN                     NaN                NaN
#
# ...

# %%
data.drop(['Message'], axis = 1)

global_list = {'Global__NewConfirmed': [812078.0],
              'Global__TotalConfirmed': [88847614.0],
               'Global__NewDeaths': [14780.0],
               'Global__NewRecovered': [297545.0],
               'Global__TotalRecovered': [49384889.0]
              }

global_data = pd.DataFrame(global_list)

# %%
global_data
# Out:
#    Global__NewConfirmed  Global__TotalConfirmed  Global__NewDeaths  \
# 0              812078.0              88847614.0            14780.0
#
#    Global__NewRecovered  Global__TotalRecovered
# 0              297545.0              49384889.0

# %%
data =data.drop(['Message', 'Global__NewConfirmed', 'Global__TotalConfirmed', 'Global__NewDeaths', 'Global__TotalDeaths', 'Global__NewRecovered', 'Global__TotalRecovered'], axis = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Countries__Country         192 non-null    object
#  1   Countries__CountryCode     191 non-null    object
#  2   Countries__Slug            192 non-null    object
#  3   Countries__NewConfirmed    192 non-null    int64
#  4   Countries__TotalConfirmed  192 non-null    int64
#  5   Countries__NewDeaths       192 non-null    int64
#  6   Countries__TotalDeaths     192 non-null    int64
#  7   Countries__NewRecovered    192 non-null    int64
#  8   Countries__TotalRecovered  192 non-null    int64
#  9   Countries__Date            192 non-null    object
#  10  Date                       1 non-null      object
# dtypes: int64(6), object(5)
# memory usage: 16.6+ KB

# %%
data.describe()
# Out:
#        Countries__NewConfirmed  Countries__TotalConfirmed  \
# count               192.000000               1.920000e+02
# mean               4229.572917               4.627480e+05
# std               21733.797220               1.885217e+06
# min                   0.000000               0.000000e+00
# 25%                   3.000000               5.119750e+03
# 50%                 253.000000               4.752450e+04
# 75%                1531.750000               2.089855e+05
# max              283204.000000               2.186277e+07
#
#        Countries__NewDeaths  Countries__TotalDeaths  Countries__NewRecovered  \
# count            192.000000              192.000000               192.000000
# mean              76.979167             9965.135417              1549.713542
# std              306.873731            35291.090174              5014.690918
# min                0.000000                0.000000                 0.000000
# ...
